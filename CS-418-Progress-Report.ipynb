# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

import sys
sys.path.insert(1, './lib/')

# %% [markdown]
# # Discovering Classic Rock Subgenres
# ### Team Diatonics | CS 418 | Spring 2020
#
# ### Team Members
# * Leopoldo Gomez (`lgomez36@uic.edu`, `pologomez`), Matthew Searcy (`msearc2@uic.edu`, `MatthewSearcy`),  Matt Rusnaczyk (`mrusna4@uic.edu`, `mrusnaczyk`), Faraz Shakir (`fshaki3@uic.edu`, `FShakir`), Mahdi Moghaddam (`mmogha2@uic.edu`, `mahdimo5595`)
#
# ------

# %% [markdown]
# ## Project Introduction
# In it's current form, the main idea of this project is to see if a clustering method can be used to subdivide a large pool of songs that are deemed to be part of the same genre into smaller subgenres. A potential audience for this analysis would be people who are trying to get into a new gerne. Being able to listen to a selection of songs from each subgroup could make it easier to figure out what type of bands they'd enjoy listening to.
#
# For our preliminary exploration into this topic we decided to use a precompiled [dataset](https://github.com/fivethirtyeight/data/blob/master/classic-rock/classic-rock-song-list.csv) of classic rock songs and get their audio features via spotify's API. We decided to use rock as our genre for this because it is one of the broadest genres of music with many distinct characteristic sounds and sub-cultures. If the preliminary results are fruitful we may continue on to broadening the genres we cluster from.

# %% [markdown]
# ## Changes to Scope of Project
# ### Spotify Listening Trends Based on Time of Year
#    Originally, our project was going to focus on the songs that gain popularity at different times of the year. We wondered if there was some correspondence between the properties of those songs and the time at which they reached peak popularity and see if we could predict the optimal time of year to release a new song given its properties.
#    Our course of action was to fetch the top 100 songs from the Billboard charts every week of the year for the past 20 years. We would then retrieve the songs' properties using the Spotify API and organize the data for comparison and use machine learning to develop a way of classifying a song into seasons based on its properties.
#
#    We decided to change our project's scope for a few reasons. When we examined the properties of the songs we gathered, virtually every week had a wide variety of levels of energy, key, loudness, etc. We concluded that there wasn't significance in the seasonality of the songs and that would likely lead to an inaccurate classification model. Since the hot-100 charts features songs of all varieties, we decided we'd have to hone in on a type of music to make the properties of the songs more similar. Additionally, a song that is on the Billbord hot-100 list often remains on the list for weeks, or even months. This resulted in complications in identifying the season that the song gained popularity, and would likely affect the learning.

# %% [markdown]
# ## Data Acquisition and Cleaning

# %% [markdown]
# Our analysis is based on two sets of data. The first is the [Classic Rock Song List from FiveThirtyEight](https://github.com/fivethirtyeight/data/blob/master/classic-rock/classic-rock-song-list.csv); the second is the audio features data made available by Spotify through their [RESTful API](https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/).

# %% [markdown]
# First, we read in the data from the classic rock songs dataset, then we transform the data into a list consisting of each track and artist concatenated into one string. Converting into this format allows us to more easily search for the tracks in Spotify later on.

# %%
import data_acquisition_cleaning as data
raw_song_data = data.load_song_data()
title_artist = data.get_title_artist(raw_song_data)

# %% [markdown]
# Next, we take the title/artist strings we generated earlier, and retrieve the corresponding Spotify resource URLs for each:

# %%
# %%capture
import spotify
spotify_client = spotify.get_spotify_client()
tracks_to_query = spotify.get_spotify_resource_urls(title_artist, spotify_client)

# %% [markdown]
# Then, we use the Spotify API to retrieve the audio features for each of the songs in the list, and add the track name and artist back in:

# %%
# %%capture
tracks_with_audio_features = spotify.audio_features(tracks_to_query, spotify_client)
tracks_with_audio_features.to_csv("tracks_with_audio_features.csv",index=False)

# %%
tracks_with_audio_features = pd.read_csv("tracks_with_audio_features.csv")

# %% [markdown]
# And this is the resulting dataset:

# %%
tracks_with_audio_features.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.425   0.681    1    -8.604       0.0316       0.02290
# 1         0.418   0.775    4    -9.591       0.0333       0.05310
# 2         0.567   0.559    9   -10.175       0.0288       0.00888
# 3         0.659   0.505    0   -12.773       0.0302       0.05300
# 4         0.646   0.426    0   -10.629       0.0480       0.08580
#
#    instrumentalness  liveness  valence    tempo                   title  \
# 0          0.000219    0.0543    0.933  131.011        Caught Up in You
# 1          0.001250    0.0932    0.845  123.524            Fantasy Girl
# 2          0.001310    0.0764    0.898  127.227         Hold On Loosely
# 3          0.000000    0.0544    0.879  128.295  Rockin' Into the Night
# 4          0.072700    0.0746    0.462  124.794       Art For Arts Sake
#
#         artist
# 0  .38 Special
# 1  .38 Special
# 2  .38 Special
# 3  .38 Special
# 4         10cc

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# As the name of the dataset would imply (Classic Rock Song List), the scope of the music we are studying is limited to a subset of popular classic rock tracks. The data was collected by [FiveThirtyEight](https://fivethirtyeight.com/features/why-classic-rock-isnt-what-it-used-to-be/) by monitoring the track histories of 25 classic rock stations across the U.S. Below are the artists included in the dataset, and the number of their songs that are listed:

# %%
data.get_artists_and_song_count(raw_song_data)
# Out:
#         Artist Name  Num Songs Included
# 393     The Beatles                 100
# 229    Led Zeppelin                  69
# 321  Rolling Stones                  55
# 453       Van Halen                  44
# 291      Pink Floyd                  39
# ..              ...                 ...
# 131        Everlast                   1
# 322  Rory Gallagher                   1
# 323     Royal Bliss                   1
# 129           Eve 6                   1
# 474            a-ha                   1
#
# [475 rows x 2 columns]

# %%
import viz
viz.get_release_year_distribution_graph(raw_song_data)

# %% [markdown]
# If we take a closer look at the data, we can see that each row represents one song and its Spotify properties:

# %%
tracks_with_audio_features.head(1)
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.425   0.681    1    -8.604       0.0316        0.0229
#
#    instrumentalness  liveness  valence    tempo             title       artist
# 0          0.000219    0.0543    0.933  131.011  Caught Up in You  .38 Special

# %% [markdown]
# The data is also not aggregated in any way, as all of the rows from the Classic Rock Song List dataset were each one track, and the Spotify data listed in each row is relevant only to the song in that row.

# %%
eda_data = tracks_with_audio_features.copy().dropna()
try:
    eda_data = eda_data.drop(columns=['cluster', 'tempo'])
except:
    None
eda_data.describe()
# Out:
#        danceability       energy          key     loudness  speechiness  \
# count   2174.000000  2174.000000  2174.000000  2174.000000  2174.000000
# mean       0.524477     0.688849     5.018859    -8.948205     0.052342
# std        0.140198     0.193194     3.509911     3.334652     0.039931
# min        0.000000     0.012400     0.000000   -23.340000     0.000000
# 25%        0.432000     0.554000     2.000000   -11.236250     0.032400
# 50%        0.531000     0.716500     5.000000    -8.743000     0.039900
# 75%        0.622000     0.847750     9.000000    -6.362250     0.056100
# max        0.952000     0.995000    11.000000    -1.525000     0.507000
#
#        acousticness  instrumentalness     liveness      valence        tempo
# count   2174.000000       2174.000000  2174.000000  2174.000000  2174.000000
# mean       0.184015          0.068094     0.206657     0.601030   124.163087
# std        0.219742          0.184148     0.189130     0.228826    27.001113
# min        0.000001          0.000000     0.012000     0.000000     0.000000
# 25%        0.015500          0.000007     0.086400     0.429000   105.414000
# 50%        0.090100          0.000472     0.131500     0.613500   123.421000
# 75%        0.290750          0.015150     0.269750     0.788000   139.775000
# max        0.971000          0.949000     0.992000     0.990000   215.918000

# %%
viz.spotify_property_dist_graph(eda_data)
plt.show()

# %% [markdown]
# ---
# ## Machine Learning Analysis

# %%
import ml_analysis as ml
# scalling loudness, key, and tempo so the values of all features are between 0 and 1
scaler = MinMaxScaler()
ml.scale_columns(['loudness', 'key', 'tempo'], tracks_with_audio_features, scaler)

# %%
(elbow, silhouette) = ml.sil_elb(tracks_with_audio_features)

# %%
plt.plot(range(50,1500,50), elbow)

# %%
plt.plot(range(50,1500,50), silhouette)

# %%
(tracks_with_audio_features,center) = ml.cluster_songs(tracks_with_audio_features, 50)
center.to_csv("center.csv", index=False)

# %%
tracks_with_audio_features.head()
# Out:
#    danceability  energy       key  loudness  speechiness  acousticness  \
# 0         0.425   0.681  0.090909  0.675499       0.0316       0.02290
# 1         0.418   0.775  0.363636  0.630254       0.0333       0.05310
# 2         0.567   0.559  0.818182  0.603484       0.0288       0.00888
# 3         0.659   0.505  0.000000  0.484391       0.0302       0.05300
# 4         0.646   0.426  0.000000  0.582672       0.0480       0.08580
#
#    instrumentalness  liveness  valence     tempo                   title  \
# 0          0.000219    0.0543    0.933  0.606763        Caught Up in You
# 1          0.001250    0.0932    0.845  0.572088            Fantasy Girl
# 2          0.001310    0.0764    0.898  0.589238         Hold On Loosely
# 3          0.000000    0.0544    0.879  0.594184  Rockin' Into the Night
# 4          0.072700    0.0746    0.462  0.577969       Art For Arts Sake
#
#         artist  cluster
# 0  .38 Special        0
# 1  .38 Special       24
# 2  .38 Special       38
# 3  .38 Special       40
# 4         10cc       29

# %%
center
# Out:
#       danceability  energy       key  loudness  speechiness  acousticness  \
# 509          0.608   0.768  0.090909  0.615586       0.0364      0.101000
# 1667         0.538   0.899  0.818182  0.772909       0.0457      0.006610
# 1779         0.299   0.329  0.272727  0.607105       0.0279      0.756000
# 1173         0.500   0.824  0.363636  0.801925       0.0388      0.000160
# 1370         0.487   0.464  0.363636  0.451341       0.0353      0.105000
# 813          0.516   0.319  0.636364  0.533165       0.0343      0.739000
# 429          0.624   0.815  0.818182  0.586661       0.0425      0.003430
# 1063         0.342   0.874  0.181818  0.766674       0.0653      0.095700
# 523          0.609   0.611  0.000000  0.647811       0.0298      0.513000
# 939          0.480   0.739  0.363636  0.808801       0.0373      0.092300
# 1301         0.275   0.216  0.454545  0.436489       0.0345      0.768000
# 1928         0.535   0.668  0.636364  0.503919       0.0366      0.040700
# 623          0.366   0.940  0.090909  0.835251       0.0696      0.000769
# 500          0.632   0.397  0.636364  0.480633       0.0265      0.536000
# 1344         0.630   0.486  0.818182  0.492001       0.0329      0.126000
# 788          0.672   0.897  0.181818  0.844373       0.0541      0.078600
# 403          0.490   0.758  0.636364  0.772358       0.0297      0.000671
# 1809         0.629   0.857  0.818182  0.746321       0.0705      0.015700
# 1223         0.331   0.733  0.181818  0.672427       0.0468      0.088700
# 570          0.420   0.398  0.363636  0.445290       0.0250      0.219000
# 96           0.345   0.745  0.181818  0.564703       0.0327      0.365000
# 674          0.537   0.701  0.090909  0.661334       0.0335      0.097200
# 2091         0.402   0.922  0.727273  0.753060       0.0669      0.012100
# 1975         0.445   0.401  0.000000  0.659088       0.0341      0.029800
# 376          0.435   0.618  0.363636  0.547742       0.0324      0.060100
# 715          0.595   0.717  0.818182  0.608251       0.0747      0.606000
# 2171         0.580   0.885  0.000000  0.833647       0.0715      0.100000
# 1650         0.567   0.455  0.818182  0.616273       0.0479      0.242000
# 38           0.532   0.767  0.636364  0.817373       0.0574      0.002870
# 8            0.565   0.564  0.181818  0.609489       0.0292      0.161000
# 639          0.357   0.653  0.818182  0.815311       0.0654      0.082800
# 351          0.581   0.713  0.818182  0.671373       0.0294      0.000159
# 254          0.449   0.424  0.636364  0.425395       0.0323      0.320000
# 159          0.691   0.726  0.454545  0.732844       0.0543      0.138000
# 977          0.442   0.744  0.181818  0.595599       0.0574      0.001380
# 1979         0.542   0.492  0.181818  0.523172       0.0256      0.467000
# 1296         0.298   0.327  0.818182  0.409030       0.0485      0.673000
# 497          0.356   0.331  0.636364  0.562686       0.0435      0.445000
# 1662         0.579   0.647  0.727273  0.599083       0.0301      0.107000
# 492          0.667   0.755  0.818182  0.737749       0.0690      0.096600
# 482          0.789   0.494  0.090909  0.441806       0.0456      0.092300
# 1454         0.327   0.920  0.818182  0.830484       0.0611      0.144000
# 592          0.446   0.731  0.181818  0.597662       0.0519      0.243000
# 1285         0.454   0.650  0.363636  0.602750       0.0437      0.407000
# 1016         0.488   0.892  0.181818  0.743021       0.0496      0.076300
# 923          0.681   0.373  0.181818  0.464818       0.0568      0.633000
# 378          0.413   0.711  0.181818  0.711620       0.0556      0.003650
# 418          0.582   0.748  0.363636  0.798075       0.0521      0.432000
# 811          0.541   0.855  0.818182  0.746367       0.0625      0.339000
# 701          0.637   0.890  0.636364  0.846573       0.0677      0.119000
#
#       instrumentalness  liveness  valence     tempo  \
# 509           0.000001    0.0942    0.748  0.614581
# 1667          0.004900    0.1300    0.702  0.628188
# 1779          0.010500    0.0559    0.392  0.612649
# 1173          0.001610    0.0916    0.539  0.556345
# 1370          0.000170    0.0767    0.214  0.451699
# 813           0.000983    0.1290    0.305  0.489556
# 429           0.622000    0.1750    0.758  0.598334
# 1063          0.000893    0.8520    0.590  0.558971
# 523           0.000000    0.0930    0.916  0.564270
# 939           0.000000    0.2390    0.250  0.578414
# 1301          0.897000    0.0832    0.181  0.539038
# 1928          0.000001    0.3410    0.720  0.623227
# 623           0.000094    0.1880    0.369  0.602997
# 500           0.042100    0.1060    0.731  0.512130
# 1344          0.000019    0.1110    0.835  0.577316
# 788           0.000006    0.3890    0.777  0.510791
# 403           0.484000    0.0920    0.435  0.519243
# 1809          0.003960    0.7550    0.528  0.538417
# 1223          0.001740    0.9470    0.380  0.595189
# 570           0.360000    0.2580    0.267  0.359808
# 96            0.735000    0.1900    0.879  0.486564
# 674           0.000000    0.0832    0.583  0.560023
# 2091          0.000050    0.1690    0.301  0.602469
# 1975          0.000000    0.0684    0.180  0.609537
# 376           0.002820    0.1670    0.695  0.601668
# 715           0.002860    0.3550    0.514  0.510550
# 2171          0.001570    0.1460    0.788  0.673427
# 1650          0.000003    0.1180    0.580  0.571587
# 38            0.000513    0.3900    0.755  0.589858
# 8             0.000000    0.1140    0.454  0.622250
# 639           0.000000    0.0844    0.522  0.818121
# 351           0.006490    0.1280    0.434  0.526918
# 254           0.000002    0.1070    0.259  0.581211
# 159           0.000000    0.1100    0.868  0.455812
# 977           0.651000    0.1660    0.244  0.592827
# 1979          0.001050    0.0863    0.580  0.477329
# 1296          0.905000    0.0786    0.333  0.604739
# 497           0.000000    0.8910    0.263  0.518692
# 1662          0.000007    0.0850    0.738  0.502459
# 492           0.000069    0.0523    0.883  0.507299
# 482           0.000408    0.1440    0.826  0.484411
# 1454          0.840000    0.7740    0.439  0.777943
# 592           0.000000    0.0935    0.723  0.711715
# 1285          0.049800    0.5890    0.720  0.556480
# 1016          0.486000    0.2660    0.675  0.613909
# 923           0.001130    0.0751    0.623  0.571620
# 378           0.000227    0.4160    0.538  0.596768
# 418           0.000000    0.0707    0.433  0.533212
# 811           0.000002    0.0821    0.820  0.653683
# 701           0.000067    0.1030    0.923  0.591377
#
#                                           title  \
# 509                        Take Me Home Tonight
# 1667                                Dog Eat Dog
# 1779                  The Long And Winding Road
# 1173                            Come As You Are
# 1370                             Lunatic Fringe
# 813                               Load Out/Stay
# 429                              Space Truckin'
# 1063                          Sweet Jane (Live)
# 523                         Sweet Talkin' Woman
# 939                            Send Her My Love
# 1301                   The Great Gig In the Sky
# 1928                           TALK OF THE TOWN
# 623                                 Best of You
# 500                             Tequila Sunrise
# 1344                               Pride of Man
# 788                           I Want A New Drug
# 403                                      Heroes
# 1809                                   Soul Man
# 1223                                        Jet
# 570                                 Let It Grow
# 96                                      Jessica
# 674                               My Sweet Lord
# 2091                   Somebody Get Me A Doctor
# 1975                    We're Not Gonna Take It
# 376                                     Suzie Q
# 715                      Turn On Your Lovelight
# 2171                                       Tush
# 1650                        Love Is Like Oxygen
# 38                  You Shook Me All Night Long
# 8                                    What's Up?
# 639                               Juke Box Hero
# 351                                 Monkey Bars
# 254                                      Amanda
# 159                            Don't Ask Me Why
# 977                        Long Stick Goes Boom
# 1979                               Get Together
# 1296  Set The Controls For The Heart Of The Sun
# 497                          Seven Bridges Road
# 1662                                I'm Leaving
# 492                       Life in the Fast Lane
# 482                      Right Place Wrong Time
# 1454                              THE LAST TIME
# 592                                       Signs
# 1285                               Have a Cigar
# 1016                         Misty Mountain Hop
# 923                       I CAN SEE CLEARLY NOW
# 378                        The Midnight Special
# 418                            California Girls
# 811                                   Boulevard
# 701                      We're an American Band
#
#                              artist  cluster
# 509                     Eddie Money        0
# 1667                     Ted Nugent        1
# 1779                    The Beatles        2
# 1173                        Nirvana        3
# 1370                      Red Rider        4
# 813                  Jackson Browne        5
# 429                     Deep Purple        6
# 1063                       Lou Reed       18
# 523        Electric Light Orchestra        8
# 939                         Journey        9
# 1301                     Pink Floyd       10
# 1928                 The Pretenders       11
# 623                    Foo Fighters       12
# 500                          Eagles       13
# 1344  Quicksilver Messenger Service       14
# 788           Huey Lewis & The News       15
# 403                     David Bowie       16
# 1809             The Blues Brothers       17
# 1223         Paul McCartney & Wings       18
# 570                    Eric Clapton       19
# 96             Allman Brothers Band       20
# 674                 George Harrison       21
# 2091                      Van Halen       22
# 1975                        The Who       23
# 376    Creedence Clearwater Revival       24
# 715                   Grateful Dead       25
# 2171                         ZZ Top       26
# 1650                          Sweet       27
# 38                            AC/DC       28
# 8                     4 Non Blondes       29
# 639                       Foreigner       30
# 351                     Coney Hatch       31
# 254                          Boston       32
# 159                      Billy Joel       33
# 977                          Krokus       34
# 1979                The Youngbloods       35
# 1296                     Pink Floyd       36
# 497                          Eagles       37
# 1662                          Taxxi       38
# 492                          Eagles       39
# 482                        Dr. John       40
# 1454                 Rolling Stones       41
# 592        Five Man Electrical Band       42
# 1285                     Pink Floyd       43
# 1016                   Led Zeppelin       44
# 923                     Johnny Nash       45
# 378    Creedence Clearwater Revival       46
# 418                  David Lee Roth       47
# 811                  Jackson Browne       48
# 701             Grand Funk Railroad       49

# %% [markdown]
# Now, we can recommend similar songs to users based on the cluster that they belong to. For example, someone who listens to 'Back in Black' might also enjoy the following songs:

# %%
ml.recommend('Back In Black', "AC/DC", tracks_with_audio_features, spotify_client,tracks_to_query).head(10)
# Out:
#               artist              title
# 11             AC/DC      Back In Black
# 27             AC/DC      Night Prowler
# 64         Aerosmith  Seasons of Wither
# 67         Aerosmith  Toys in the Attic
# 79      Alice Cooper            Elected
# 89   Alice In Chains            Rooster
# 139      Bad Company      Shooting Star
# 179     Billy Squier     She's a Runner
# 184    Black Sabbath           Iron Man
# 190    Black Sabbath           War Pigs

# %%
ml.recommend('Roar', "katy perry", tracks_with_audio_features, spotify_client,tracks_to_query).head(10)
# Out:
#                artist                    title
# 42          Aerosmith    Baby, Please Don't Go
# 47          Aerosmith                   Cryin'
# 90    Alice In Chains               Them Bones
# 116              Asia      Only Time Will Tell
# 200  Blue Oyster Cult  (Don't Fear) The Reaper
# 249          Bon Jovi     Wanted Dead or Alive
# 305              Bush                 Comedown
# 306              Bush              Machinehead
# 437       Def Leppard     On Through The Night
# 450               Dio               Holy Diver

# %% [markdown]
# ### Visualizing the results

# %%
tsnedf = tracks_with_audio_features.copy().drop(columns=['artist', 'title', 'cluster'])
model = TSNE(n_components=2, random_state=0, perplexity=50, learning_rate=900)
tsne_object = model.fit_transform(tsnedf)
tsne_df = pd.DataFrame(data=tsne_object, columns=('TSNE Dimension 1', 'TSNE Dimension 2'))
tsne_df['cluster'] = tracks_with_audio_features.cluster
sns.FacetGrid(tsne_df, hue='cluster', height=5).map(plt.scatter, 'TSNE Dimension 1', 'TSNE Dimension 2', 'cluster')
plt.show()

# %%
dataframe['baseline'] = 0
i = 0
j = 0
while(True):
    if j+42 < len(urls):
        dataframe.loc[j:j+42,:].baseline = i
        j = j+43
        i = i+1
    else:
        dataframe.loc[j:len(urls),:].baseline = i
        break

# %%
center2 = center.copy()
plot = sns.boxplot(
    data=center2.drop(columns=['tempo', 'loudness', 'key', 'cluster'])
)
plot.set(
    xlabel='Spotify Track Property', 
    ylabel='Scaled Value'
)
plot.set_xticklabels(
    plot.get_xticklabels(),
    rotation=75
)
# Out:
# [Text(0, 0, 'danceability'),
#  Text(0, 0, 'energy'),
#  Text(0, 0, 'speechiness'),
#  Text(0, 0, 'acousticness'),
#  Text(0, 0, 'instrumentalness'),
#  Text(0, 0, 'liveness'),
#  Text(0, 0, 'valence')]

# %%
import viz
center = pd.read_csv("center.csv")
plot1 = viz.compare_centers(center)

# %% [markdown]
# ## Reflection
# The hardest parts of the project have been figuring out what data to acquire and cleaning it and proper version control with Jupyter Notebooks.  The biggest initial insight we found is that our initial hypothesis of seasonality in data is not true, and the low hanging fruit of Spotify data was already taken by another project.  We have used the t-SNE methodology in order to obtain a map of the clusters, representing subgenres of rock music.  We have not yet added labels to these clusters, and we still need to get a proper accuracy in spite of the unsupervised learning we have used as a base, which is also our next pressing issue.  The team is on track with the project and we foresee being able to complete it on schedule.  Despite the difficulty in figuring out the project's goals, we believe it is worth proceeding as we now have a goal and a means to get there
#
# ---

# %% [markdown]
# ## Next Steps
# Our next steps are mainly to work on our machine learing process. We need to add labels to our clusters and try to improve our accuracy.
